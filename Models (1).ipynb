# %%
# Importing Important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv('preprocessed_data_new.csv')
df.head()
# Out:
#          Date      Rain     T_max     T_min  Kerala_Trends  Kerala_Tourism  \
# 0  01-01-2010 -0.866119 -0.828886 -1.848258       3.040989        2.547672
# 1  01-02-2010 -0.814907  0.659512 -1.413850       2.161667        2.756409
# 2  01-03-2010 -0.636138  1.586710  0.040471       3.627204        3.034726
# 3  01-04-2010 -0.530310  1.830709  1.425539       1.722006        2.686830
# 4  01-05-2010 -0.460514  1.434210  0.500062       2.601328        3.243464
#
#    Kerala_Weather  Kerala_Travel  Recreation  Geographic_Reference    Travel  \
# 0       -0.891865       2.468694           0              3.040989  2.460477
# 1       -0.793260       1.785864           0              2.161667  1.778408
# 2       -0.300238       2.810109           0              3.627204  2.801511
# 3       -0.596051       2.297986           6              1.722006  2.289959
# 4        0.784411       3.151524           0              2.601328  3.142546
#
#       Hotel  Air Travel  Bus & Rail  Car & Taxi Rental  Tourist Destinations  \
# 0  3.003711    0.085313    1.975207                  5              2.130383
# 1  1.901172   -0.809393    1.617018                  4              1.556252
# 2  2.881206    0.980018    1.885659                  3              2.048364
# 3  2.023676   -0.697555    1.975207                  0              2.048364
# 4  2.513694    0.420827    2.422943                 14              2.868551
#
#    Travel Agencies  Tourist Arrivals
# 0         2.575467           94966.0
# 1         2.698937           94185.0
# 2         3.192819           66854.0
# 3         2.451996           57215.0
# 4         3.192819           28938.0

# %%
x = pd.read_csv('shimla_preprocessed_data.csv')
target = x['Tourist Arrivals']
target.head()
# Out:
# 0    183556.0
# 1    174609.0
# 2    198760.0
# 3    395110.0
# 4    390553.0
# Name: Tourist Arrivals, dtype: float64

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rain                     156 non-null    float64
#  1   T_max                    156 non-null    float64
#  2   T_min                    156 non-null    float64
#  3   Shimla                   156 non-null    float64
#  4   Shimla_Tourism           156 non-null    float64
#  5   Shimla_Weather           156 non-null    float64
#  6   Shimla_Travel            156 non-null    float64
#  7   Recreation               156 non-null    int64
#  8   Geographic Reference     156 non-null    float64
#  9   Travel                   156 non-null    float64
#  10  Hotels & Accommodations  156 non-null    float64
#  11  Air Travel               156 non-null    float64
#  12  Bus & Rail               156 non-null    float64
#  13  Car & Taxi               156 non-null    int64
#  14  Tourist Destinations     156 non-null    float64
#  15  Travel Agencies          156 non-null    int64
#  16  Tourist Arrivals         156 non-null    float64
# dtypes: float64(14), int64(3)
# memory usage: 20.8 KB

# %%
df.isnull().sum()
# Out:
# Rain                       0
# T_max                      0
# T_min                      0
# Shimla                     0
# Shimla_Tourism             0
# Shimla_Weather             0
# Shimla_Travel              0
# Recreation                 0
# Geographic Reference       0
# Travel                     0
# Hotels & Accommodations    0
# Air Travel                 0
# Bus & Rail                 0
# Car & Taxi                 0
# Tourist Destinations       0
# Travel Agencies            0
# Tourist Arrivals           0
# dtype: int64

# %%
df = df.replace(to_replace="<1",
           value=0.5)

# %%
type(df['Recreation'][1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Recreation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-dd4537c57de4> in <cell line: 1>()
# ----> 1 type(df['Recreation'][1])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Recreation'

# %%
# df = df.replace(to_replace="Jan",
#            value=1)
# df = df.replace(to_replace="Feb",
#            value=2)
# df = df.replace(to_replace="Mar",
#            value=3)
# df = df.replace(to_replace="Apr",
#            value=4)
# df = df.replace(to_replace="May",
#            value=5)
# df = df.replace(to_replace="Jun",
#            value=6)
# df = df.replace(to_replace="Jul",
#            value=7)
# df = df.replace(to_replace="Aug",
#            value=8)
# df = df.replace(to_replace="Sep",
#            value=9)
# df = df.replace(to_replace="Oct",
#            value=10)
# df = df.replace(to_replace="Nov",
#            value=11)
# df = df.replace(to_replace="Dec",
#            value=12)

# %%
# df = df.drop(['Year'], axis = 1)
df
# Out:
#          Rain     T_max     T_min    Shimla  Shimla_Tourism  Shimla_Weather  \
# 0   -0.397005 -1.650689 -1.650689  0.838802        2.710890       -0.180415
# 1   -0.397005 -1.538694 -1.538694  0.175322        2.960978       -0.857861
# 2   -0.272100 -0.207028 -0.207028  1.870884        3.523676       -0.796275
# 3   -0.397005 -0.035200 -0.035200  2.534365        4.273940       -0.426759
# 4    0.272774  0.659783  0.659783  3.419006        5.336814       -0.549931
# ..        ...       ...       ...       ...             ...             ...
# 151  1.674261  1.000033  1.000033 -0.783040       -0.790342        0.004343
# 152 -0.274160  1.179930  1.179930 -0.635600       -0.790342       -0.118829
# 153 -0.397005  0.716026  0.716026 -0.783040       -0.727820       -0.303587
# 154 -0.397005 -0.109193 -0.109193 -0.561879       -0.790342       -0.118829
# 155 -0.397005 -0.947744 -0.947744  0.543922       -0.727820        1.543992
#
#      Shimla_Travel  Recreation  Geographic Reference    Travel  \
# 0         3.173291           0              0.027634  0.572920
# 1         1.698026           0              0.315025  0.572920
# 2         3.665047           0              1.579549  1.957514
# 3         3.337210           0              1.694506  2.995960
# 4         4.648557           0              2.729116  3.342108
# ..             ...         ...                   ...       ...
# 151      -0.924668           0             -0.489671 -0.950133
# 152      -0.924668           0             -0.489671 -0.950133
# 153      -0.760749           0              0.027634 -0.811674
# 154      -0.432913           0              0.085112 -0.673215
# 155      -0.596831           0              1.062244  0.296001
#
#      Hotels & Accommodations  Air Travel  Bus & Rail  Car & Taxi  \
# 0                   0.065293   -0.842740   -0.117647           0
# 1                   1.917246    1.692445    0.787077          22
# 2                   2.578657    2.416784    1.304062           0
# 3                   3.901480    4.408715    1.239439           0
# 4                   3.901480    4.589800    3.372002           0
# ..                       ...         ...         ...         ...
# 151                -0.992965   -0.842740   -0.893125           1
# 152                -0.992965   -0.299486   -0.893125           1
# 153                -0.992965   -0.299486   -0.570009           2
# 154                -0.728401   -0.661656   -0.505386           1
# 155                -0.331554   -0.299486    0.140845           2
#
#      Tourist Destinations  Travel Agencies  Tourist Arrivals
# 0                1.335399                0     183556.000000
# 1                0.579391                2     174609.000000
# 2                2.427411                0     198760.000000
# 3                3.435422                2     395110.000000
# 4                3.015418                5     390553.000000
# ..                    ...              ...               ...
# 151             -1.016627                0     102949.890137
# 152             -0.932626                0     111659.695801
# 153             -1.100627                0     115464.112793
# 154             -0.848625                0     110457.591797
# 155             -0.176617                0     195949.932617
#
# [156 rows x 17 columns]

# %%
df["Recreation"] = df["Recreation"].astype(int)
df["Car & Taxi"] = df["Car & Taxi"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Car & Taxi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a1aaa4535071> in <cell line: 2>()
#       1 df["Recreation"] = df["Recreation"].astype(int)
# ----> 2 df["Car & Taxi"] = df["Car & Taxi"].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Car & Taxi'

# %%
df = df.drop(["Date"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-540c0b26ca30> in <cell line: 1>()
# ----> 1 df = df.drop(["Date"], axis = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Date'] not found in axis"

# %%
import xgboost as xgb
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X = df.drop(["Tourist Arrivals"], axis=1)
y = df["Tourist Arrivals"]

#X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# # X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X = X
y = y

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
#X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)



reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.253668942189889
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_W.drop(["Region", "May-21"], axis=1)
# y = df_W["May-21"]


#X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X = X
y = y

#X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.253668942189889
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df.drop(["Warehouse id", "SKU id", "May-21"], axis=1)
# y = df["May-21"]



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

#X1 = X[["Region", "Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor

X = X
y = y

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# X['Region'] = X['Region'].replace({'NORTH': 1}, regex=True)
# X['Region'] = X['Region'].replace({'WEST': 2}, regex=True)
# X['Region'] = X['Region'].replace({'EAST': 3}, regex=True)
# X['Region'] = X['Region'].replace({'SOUTH': 4}, regex=True)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
print(reg.score(X_test, y_test))
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# -2.374843164000153
# 0.7450551823757705

# %%
from sklearn.ensemble import ExtraTreesClassifier
# Building the model
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,
                                        criterion ='entropy', max_features = 2)

# X = df.drop(["May-21"], axis=1)
# y = df["May-21"]



# Training the model
y = y.to_numpy()
extra_tree_forest.fit(X, y)

# Computing the importance of each feature
feature_importance = extra_tree_forest.feature_importances_

# Normalizing the individual importances
feature_importance_normalized = np.std([tree.feature_importances_ for tree in
                                        extra_tree_forest.estimators_],
                                        axis = 0)

from matplotlib.pyplot import figure

figure(figsize=(40, 20), dpi=80)
# Plotting a Bar Graph to compare the models
plt.bar(X.columns, feature_importance_normalized, width=0.5)
plt.xlabel('Feature Labels')
plt.ylabel('Feature Importances')
plt.title('Comparison of different Feature Importances')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-c3de70cdfced> in <cell line: 13>()
#      11 # Training the model
#      12 y = y.to_numpy()
# ---> 13 extra_tree_forest.fit(X, y)
#      14
#      15 # Computing the importance of each feature
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     383         self.n_outputs_ = y.shape[1]
#     384
# --> 385         y, expanded_class_weight = self._validate_y_class_weight(y)
#     386
#     387         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     744
#     745     def _validate_y_class_weight(self, y):
# --> 746         check_classification_targets(y)
#     747
#     748         y = np.copy(y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.linear_model import ElasticNet
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
x = sc_x.fit_transform(X)
# y = y.to_numpy()
y = y.reshape(-1,1)
y = sc_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
regressor = ElasticNet(random_state=0)

# %%
regressor.fit(x_train, y_train)
# Out:
# ElasticNet(random_state=0)

# %%
print(regressor.score(x_test, y_test))
# Out:
# 0.15934548066696907

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae
y_pred = regressor.predict(x_test)
mae(y_pred, y_test)
# Out:
# 11.436324617929138

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
regressor = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
regressor.fit(x_train, y_train)
# Out:
# <ipython-input-35-e3a26b00eeb3>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# ExtraTreesRegressor(random_state=0)

# %%
print(regressor.score(x_test, y_test))
# Out:
# 0.42711288087882626

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae
y_pred = regressor.predict(x_test)
mae(y_pred, y_test)
# Out:
# 8.153341814370373

# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
model = lgb.LGBMRegressor()
model.fit(x_train, y_train)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000337 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 344
# [LightGBM] [Info] Number of data points in the train set: 104, number of used features: 15
# [LightGBM] [Info] Start training from score 0.066654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LGBMRegressor()

# %%
y_pred = model.predict(x_test)

# %%
print(metrics.r2_score(y_test, y_pred))
# Out:
# 0.4244184816620251

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae

mae(y_pred, y_test)
# Out:
# 2.2198512429847286

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_N.drop(["Region", "May-21"], axis=1)
# y = df_N["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
#accuracy = accuracy_score(y_test, y_pred)
reg.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.2561254411917018

# %%
mape
# Out:
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
#accuracy = accuracy_score(y_test[0], y_pred[0])
print(reg.score(X_test, y_test))
mape
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.2561254411917018
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_W.drop(["Region", "May-21"], axis=1)
# y = df_W["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
#accuracy = accuracy_score(y_test[0], y_pred[0])
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
#accuracy = accuracy_score(y_test[0], y_pred[0])
#accuracy = accuracy_score(y_test[0], y_pred[0])
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_W.drop(["Region", "May-21"], axis=1)
# y = df_W["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)


reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_S.drop(["Region", "May-21"], axis=1)
# y = df_S["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)


reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

#X1 = X[["Region", "Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.2561254411917018
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 2.2745691119758664

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42, shuffle=False)
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
print(reg.score(X_test, y_test))
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# -2.3643023278460875
# <ipython-input-54-04e2b3a79d73>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
# 2.2745691119758664

# %%
from sklearn.ensemble import ExtraTreesClassifier
# Building the model
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,
                                        criterion ='entropy', max_features = 2)

# X = df.drop(["May-21"], axis=1)
y = df["Tourist Arrivals"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# X['Region'] = X['Region'].replace({'NORTH': 1}, regex=True)
# X['Region'] = X['Region'].replace({'WEST': 2}, regex=True)
# X['Region'] = X['Region'].replace({'EAST': 3}, regex=True)
# X['Region'] = X['Region'].replace({'SOUTH': 4}, regex=True)

# Training the model
extra_tree_forest.fit(x, y)

# Computing the importance of each feature
feature_importance = extra_tree_forest.feature_importances_

# Normalizing the individual importances
feature_importance_normalized = np.std([tree.feature_importances_ for tree in
                                        extra_tree_forest.estimators_],
                                        axis = 0)

from matplotlib.pyplot import figure

figure(figsize=(40, 20), dpi=80)
# Plotting a Bar Graph to compare the models
plt.bar(X.columns, feature_importance_normalized, width=0.5)
plt.xlabel('Feature Labels')
plt.ylabel('Feature Importances')
plt.title('Comparison of different Feature Importances')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-c1b82e120b0a> in <cell line: 17>()
#      15
#      16 # Training the model
# ---> 17 extra_tree_forest.fit(x, y)
#      18
#      19 # Computing the importance of each feature
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     383         self.n_outputs_ = y.shape[1]
#     384
# --> 385         y, expanded_class_weight = self._validate_y_class_weight(y)
#     386
#     387         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     744
#     745     def _validate_y_class_weight(self, y):
# --> 746         check_classification_targets(y)
#     747
#     748         y = np.copy(y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'continuous'

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_N.drop(["Region", "May-21"], axis=1)
# y = df_N["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)


reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.253668942189889
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df_W.drop(["Region", "May-21"], axis=1)
# y = df_W["May-21"]

# X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# #X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X1 = X[["Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
# X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# -3.253668942189889
# 0.7450551823757705

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, accuracy_score
from sklearn.model_selection import train_test_split

# X = df.drop(["Warehouse id", "SKU id", "May-21"], axis=1)
# y = df["May-21"]

# #X['SKU id'] = X['SKU id'].replace({'SKU-': ''}, regex=True)
# #X['Warehouse id'] = X['Warehouse id'].replace({'Wh-': ''}, regex=True)
# X['Region'] = X['Region'].replace({'NORTH': 1}, regex=True)
# X['Region'] = X['Region'].replace({'WEST': 2}, regex=True)
# X['Region'] = X['Region'].replace({'EAST': 3}, regex=True)
# X['Region'] = X['Region'].replace({'SOUTH': 4}, regex=True)
#X.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

#X1 = X[["Region", "Apr-21", "Sep-20", "Oct-20", "Oct-19"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)

y_pred = reg.predict(X_test)
#y_pred = pd.DataFrame(y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(reg.score(X_test, y_test))
mape
# Out:
# -3.253668942189889
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# 0.7450551823757705

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor

X = df.drop(["Tourist Arrivals"], axis=1)
y = df["Tourist Arrivals"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
print(reg.score(X_test, y_test))
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# -2.374843164000153
# 0.7450551823757705

# %%
from sklearn.ensemble import ExtraTreesClassifier
# Building the model
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,
                                        criterion ='entropy', max_features = 2)


# Training the model
extra_tree_forest.fit(X, y)

# Computing the importance of each feature
feature_importance = extra_tree_forest.feature_importances_

# Normalizing the individual importances
feature_importance_normalized = np.std([tree.feature_importances_ for tree in
                                        extra_tree_forest.estimators_],
                                        axis = 0)

from matplotlib.pyplot import figure

figure(figsize=(40, 20), dpi=80)
# Plotting a Bar Graph to compare the models
plt.bar(X.columns, feature_importance_normalized, width=0.5)
plt.xlabel('Feature Labels')
plt.ylabel('Feature Importances')
plt.title('Comparison of different Feature Importances')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-2b47d33ad0ab> in <cell line: 8>()
#       6
#       7 # Training the model
# ----> 8 extra_tree_forest.fit(X, y)
#       9
#      10 # Computing the importance of each feature
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     383         self.n_outputs_ = y.shape[1]
#     384
# --> 385         y, expanded_class_weight = self._validate_y_class_weight(y)
#     386
#     387         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     744
#     745     def _validate_y_class_weight(self, y):
# --> 746         check_classification_targets(y)
#     747
#     748         y = np.copy(y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train, y_train)
# Out:
# SVR()

# %%
print(regressor.score(x_test, y_test))
# Out:
# -2.5507695865129025

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred = pd.DataFrame(y_pred)

# %%
y_pred
# Out:
#                 0
# 0   236550.729986
# 1   236550.317052
# 2   236549.929047
# 3   236553.939290
# 4   236552.851091
# 5   236553.766806
# 6   236549.593518
# 7   236552.036951
# 8   236550.825666
# 9   236554.709046
# 10  236553.943342
# 11  236552.281241
# 12  236554.616855
# 13  236554.523504
# 14  236550.368499
# 15  236553.188984
# 16  236554.251161
# 17  236552.389491
# 18  236553.201728
# 19  236552.490645
# 20  236550.171179
# 21  236552.747807
# 22  236551.039017
# 23  236553.079540
# 24  236552.137591
# 25  236553.363734
# 26  236551.852148
# 27  236551.988465
# 28  236550.289209
# 29  236549.524011
# 30  236551.984603
# 31  236550.573086
# 32  236551.772597
# 33  236553.693439
# 34  236554.126100
# 35  236555.030093
# 36  236555.474803
# 37  236551.850042
# 38  236552.776208
# 39  236550.433060
# 40  236549.746113
# 41  236553.585588
# 42  236551.024620
# 43  236549.861813
# 44  236552.134379
# 45  236549.718086
# 46  236552.283047
# 47  236550.071506
# 48  236554.276748
# 49  236550.336900
# 50  236553.079989
# 51  236554.715594

# %%
def mape(actual, predicted):
  return (abs(actual-predicted)/actual)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae

mae(y_pred, y_test)
# Out:
# 0.3691671994433854

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Las
# [CV 5/5] END model__alpha=99.98999999999994;, score=-25048048719.037 total time=   0.0s

# %%
list([X_train.columns, importance])
# Out:
# [Index(['Rain', 'T_max', 'T_min', 'Shimla', 'Shimla_Tourism', 'Shimla_Weather',
#         'Shimla_Travel', 'Recreation', 'Geographic Reference', 'Travel',
#         'Hotels & Accommodations', 'Air Travel', 'Bus & Rail', 'Car & Taxi',
#         'Tourist Destinations', 'Travel Agencies'],
#        dtype='object'),
#  array([9.50840490e+03, 6.35190264e+03, 1.03192668e-12, 6.34727515e+04,
#         6.04823430e+03, 1.45019837e+04, 5.04235905e+03, 1.45817719e+04,
#         3.88777723e+04, 8.54595610e+04, 3.48651308e+04, 2.73002633e+03,
#         2.80539630e+04, 2.78367652e+02, 0.00000000e+00, 2.37506305e+02])]

# %%
 from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %%
print(regressor.score(X_test, y_test))
# Out:
# -2.550749018527294

# %%
Y_pred = regressor.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae

mae(Y_pred, y_test)
# Out:
# 0.3691688034392634

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
x1 = sc_x.fit_transform(x)
y = y.to_numpy()
y = y.reshape(-1,1)
y1 = sc_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.33, random_state = 42)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x1_train, y1_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
print(regressor.score(x1_test, y1_test))
# Out:
# 0.4460453781371492

# %%
y1_pred = regressor.predict(x1_test)
y1_pred = pd.DataFrame(y1_pred)

# %%
mae(y1_pred, y1_test)
# Out:
# 1.9592648270478592

# %%
pipeline = Pipeline([('scaler',StandardScaler()), ('model',Lasso())])
search = GridSearchCV(pipeline, {'model__alpha':np.arange(0.1,100,0.01)},cv = 5, scoring="neg_mean_squared_error",verbose=3)
search.fit(x1_train,y1_train)
alpha = search.best_params_
coefficients = search.best_estimator_.named_steps['model'].coef_
importance = np.abs(coefficients)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 1/5] END ...model__alpha=89.99999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=89.99999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=89.99999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=89.99999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=89.99999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.00999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.00999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.00999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.00999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.00999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.01999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.01999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.01999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.01999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.01999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.02999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.02999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.02999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.02999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.02999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.03999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.03999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.03999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.03999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.03999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.04999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.04999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.04999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.04999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.04999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.05999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.05999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.05999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.05999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.05999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.06999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.06999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.06999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.06999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.06999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.07999999999996;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.07999999999996;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.07999999999996;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.07999999999996;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.07999999999996;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.08999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.08999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.08999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.08999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.08999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.09999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.09999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.09999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.09999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.09999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.10999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.10999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.10999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.10999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.10999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.11999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.11999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.11999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.11999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.11999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.12999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.12999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.12999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.12999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.12999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.13999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.13999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.13999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.13999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.13999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.14999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.14999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.14999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.14999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.14999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.15999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.15999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.15999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.15999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.15999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.16999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.16999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.16999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.16999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.16999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.17999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.17999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90.17999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=90.17999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=90.17999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=90.18999999999996;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=90.18999999999996;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=90
999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.92999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.92999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.93999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.93999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.93999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.93999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.93999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.94999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.94999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.94999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.94999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.94999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.95999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.95999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.95999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.95999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.95999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.96999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.96999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.96999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.96999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.96999999999994;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.97999999999995;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.97999999999995;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.97999999999995;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.97999999999995;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.97999999999995;, score=-1.004 total time=   0.0s
# [CV 1/5] END ...model__alpha=99.98999999999994;, score=-1.863 total time=   0.0s
# [CV 2/5] END ...model__alpha=99.98999999999994;, score=-0.774 total time=   0.0s
# [CV 3/5] END ...model__alpha=99.98999999999994;, score=-0.817 total time=   0.0s
# [CV 4/5] END ...model__alpha=99.98999999999994;, score=-1.160 total time=   0.0s
# [CV 5/5] END ...model__alpha=99.98999999999994;, score=-1.004 total time=   0.0s

# %%
#To compare and see which are important
list([X_train.columns, importance])
# Out:
# [Index(['Rain', 'T_max', 'T_min', 'Shimla', 'Shimla_Tourism', 'Shimla_Weather',
#         'Shimla_Travel', 'Recreation', 'Geographic Reference', 'Travel',
#         'Hotels & Accommodations', 'Air Travel', 'Bus & Rail', 'Car & Taxi',
#         'Tourist Destinations', 'Travel Agencies'],
#        dtype='object'),
#  array([0.00000000e+00, 1.20977158e-01, 3.92848147e-16, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.73774450e-02,
#         0.00000000e+00, 0.00000000e+00, 1.22496862e-01, 0.00000000e+00,
#         3.02987995e-01, 0.00000000e+00, 2.48616857e-01, 0.00000000e+00])]

# %%
#To choose the columns from the dataframe

X1_train = X_train[["Dec-19", "May-20", "Jun-20", "Oct-20", "Apr-21"]]
X1_test = X_test[["Dec-19", "May-20", "Jun-20", "Oct-20", "Apr-21"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-9c7d0e049924> in <cell line: 3>()
#       1 #To choose the columns from the dataframe
#       2
# ----> 3 X1_train = X_train[["Dec-19", "May-20", "Jun-20", "Oct-20", "Apr-21"]]
#       4 X1_test = X_test[["Dec-19", "May-20", "Jun-20", "Oct-20", "Apr-21"]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Dec-19', 'May-20', 'Jun-20', 'Oct-20', 'Apr-21'], dtype='object')] are in the [columns]"

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %%
print(regressor.score(X_test, y_test))
# Out:
# -2.550749018527294

# %%
Y_pred = regressor.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae

mae(Y_pred, y_test)
# Out:
# 0.3691688034392634

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
reg = GradientBoostingRegressor(random_state=0)
reg.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
print(reg.score(x_test, y_test))
# Out:
# -5.586045710412454

# %%
from sklearn.metrics import mean_absolute_percentage_error as mae
y_pred = reg.predict(x_test)
mae(y_pred, y_test)
# Out:
# 0.4284567268447473
